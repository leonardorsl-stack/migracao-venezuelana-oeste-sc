# %% [markdown]
# # Notebook 04: Analise de Dados de Educacao
#
# **Projeto:** `migracao-venezuelana-oeste-sc`
# **Autores:** Leonardo Rafael Santos Leitao e Vicente Neves da Silva Ribeiro (UFFS)
# **Data:** Abril de 2026
#
# ---
#
# ## Objetivo
#
# Este notebook e um **placeholder** para a analise de dados de educacao da populacao venezuelana no Oeste de Santa Catarina.
#
# ## Acesso aos Dados
#
# Os dados de educacao nao estao disponiveis publicamente em bases abertas com desagregacao por nacionalidade. Sera necessario:
#
# 1. **Solicitacao LAI (Lei de Acesso a Informacao):** Enviar pedido a Secretaria de Estado da Educacao de SC (SED/SC) solicitando microdados ou tabulacoes agregadas de matriculas por nacionalidade/pais de origem.
# 2. **Portal QEdu / INEP:** Verificar se ha dados agregados no portal QEdu ou no Censo Escolar do INEP com a variavel `pais_origem`.
# 3. **Censo Escolar:** Baixar microdados do Censo Escolar e filtrar por `pais_origem` = Venezuela.
#
# ## Estrutura Esperada dos Dados
#
# Conforme o dicionario de dados (`docs/dicionario_dados.md`), esperamos as seguintes variaveis:
#
# | Variavel | Descricao |
# |:---|:---|
# | `ano` | Ano de referencia |
# | `cod_municipio` | Codigo IBGE do municipio |
# | `etapa_ensino` | Pre-escola, Fundamental, Medio, EJA, Superior |
# | `sexo` | Masculino/Feminino |
# | `idade` | Idade do estudante |
# | `nacionalidade` | Brasileira / Estrangeira |
# | `pais_origem` | Pais de origem (Venezuela) |
# | `matriculas` | Numero de matriculas |
# | `abandono` | Numero de evasoes |
# | `taxa_rendimento` | Taxa de aprovacao |
#
# ## Analises Previstas
#
# - Taxa de matricula por etapa de ensino e municipio;
# - Distorcao idade-serie;
# - Taxa de evasao escolar;
# - Comparativo entre populacao venezuelana e brasileira.
#
# > **Status:** Aguardando obtencao dos dados via LAI. Este notebook sera atualizado assim que os dados estiverem disponiveis.

# %%
# Placeholder para futura analise
print("[INFO] Notebook placeholder para analise de educacao.")
print("[INFO] Proximo passo: solicitar dados via LAI a SED/SC.")
